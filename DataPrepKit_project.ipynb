# %% [markdown]
# <a href="https://colab.research.google.com/github/nena00s/Python-Programming-Foundation-with-DataPrepKit-project/blob/main/DataPrepKit_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

class DataHandler:
    def _init_(self):
        pass

    def read_file(self, file_format, file_path):
        if file_format == 'csv':
            df = pd.read_csv(file_path)
        elif file_format == 'xlsx':
            df = pd.read_excel(file_path)
        elif file_format == 'json':
            df = pd.read_json(file_path)
        else:
            raise ValueError("Please provide a valid format (csv, excel, json)")
        return df
        # Read the CSV file

    def data_summary(self, df):
        print("Data Summary:")
        print("Number of Rows:", df.shape[0])
        print("Number of Columns:", df.shape[1])

        for column in df.columns:
            if pd.api.types.is_numeric_dtype(df[column]):
                print(f"Average Values [{column}]: {df[column].mean()}")
                print(f"Most Frequent Value [{column}]: {df[column].mode().iloc[0]}")
                print(f"Standard Deviation [{column}]: {df[column].std()}")
                print(f"Median [{column}]: {df[column].median()}")
                print(f"Minimum Value [{column}]: {df[column].min()}")
                print(f"Maximum Value [{column}]: {df[column].max()}")
                print(f"Skewness [{column}]: {df[column].skew()}")
            else:
                print(f"Count of unique values in [{column}]: {df[column].nunique()}")

    def handle_missing_values(self, df, strategy='remove', column=None, value=None):
        if strategy == 'remove':
            df = df.dropna()
        elif strategy == 'mean':
            df[column].fillna(df[column].mean(), inplace=True)
        elif strategy == 'median':
            df[column].fillna(df[column].median(), inplace=True)
        elif strategy == 'custom_value':
            df[column].fillna(value, inplace=True)
        else:
            raise ValueError("Please choose from 'remove', 'mean', 'median', 'custom_value'.")
        return df

    def handle_missing(self, df):
        print("Handling Missing Values:")
        print("1. Remove rows with missing values")
        print("2. Impute missing values with mean")
        print("3. Impute missing values with median")
        print("4. Impute missing values with a custom value")

        choice = input("Enter your choice (1/2/3/4): ")
        if choice == '1':
            df = self.handle_missing_values(df, strategy='remove')
        elif choice == '2':
            column = input("Enter the column name to impute missing values with mean: ")
            df = self.handle_missing_values(df, strategy='mean', column=column)
        elif choice == '3':
            column = input("Enter the column name to impute missing values with median: ")
            df = self.handle_missing_values(df, strategy='median', column=column)
        elif choice == '4':
            column = input("Enter the column name to impute missing values with a custom value: ")
            custom_value = input("Enter the custom value: ")
            df = self.handle_missing_values(df, strategy='custom_value', column=column, value=custom_value)
        else:
            print("Invalid choice. Please choose from 1, 2, 3, or 4.")
        return df

    def categorical_data_encoding(self, df):
        categorical_columns = df.select_dtypes(include=['object']).columns.tolist()
        for column in categorical_columns:
            df[column] = df[column].astype('category').cat.codes
        return df

    def main(self):
        file_path = input("Please enter the path of your file: ")
        file_format = file_path.split('.')[-1]
        df = self.read_file(file_format, file_path)
        print("Represent of the file:")
        print(df)

        self.data_summary(df)

        df = self.handle_missing(df)

        df = self.categorical_data_encoding(df)

        print("Final DataFrame:")
        print(df)
        self.data_summary(df)


# Instantiate and run the main function
handler = DataHandler()
handler.main()
# Out:
# Please enter the path of your file: /content/sample_data/california_housing_test.csv
# Represent of the file:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [3000 rows x 9 columns]
# Data Summary:
# Number of Rows: 3000
# Number of Columns: 9
# Average Values [longitude]: -119.58919999999999
# Most Frequent Value [longitude]: -118.26
# Standard Deviation [longitude]: 1.9949362939550175
# Median [longitude]: -118.485
# Minimum Value [longitude]: -124.18
# Maximum Value [longitude]: -114.49
# Skewness [longitude]: -0.29785763262779996
# Average Values [latitude]: 35.635389999999994
# Most Frequent Value [latitude]: 34.02
# Standard Deviation [latitude]: 2.129669523343834
# Median [latitude]: 34.27
# Minimum Value [latitude]: 32.56
# Maximum Value [latitude]: 41.92
# Skewness [latitude]: 0.45981593679052085
# Average Values [housing_median_age]: 28.845333333333333
# Most Frequent Value [housing_median_age]: 52.0
# Standard Deviation [housing_median_age]: 12.555395554955753
# Median [housing_median_age]: 29.0
# Minimum Value [housing_median_age]: 1.0
# Maximum Value [housing_median_age]: 52.0
# Skewness [housing_median_age]: 0.018513121159991593
# Average Values [total_rooms]: 2599.578666666667
# Most Frequent Value [total_rooms]: 907.0
# Standard Deviation [total_rooms]: 2155.593331625581
# Median [total_rooms]: 2106.0
# Minimum Value [total_rooms]: 6.0
# Maximum Value [total_rooms]: 30450.0
# Skewness [total_rooms]: 4.167637358501556
# Average Values [total_bedrooms]: 529.9506666666666
# Most Frequent Value [total_bedrooms]: 314.0
# Standard Deviation [total_bedrooms]: 415.6543681363229
# Median [total_bedrooms]: 437.0
# Minimum Value [total_bedrooms]: 2.0
# Maximum Value [total_bedrooms]: 5419.0
# Skewness [total_bedrooms]: 3.8633931890458686
# Average Values [population]: 1402.7986666666666
# Most Frequent Value [population]: 870.0
# Standard Deviation [population]: 1030.5430124122424
# Median [population]: 1155.0
# Minimum Value [population]: 5.0
# Maximum Value [population]: 11935.0
# Skewness [population]: 2.9496706908288868
# Average Values [households]: 489.912
# Most Frequent Value [households]: 273.0
# Standard Deviation [households]: 365.42270980552627
# Median [households]: 409.5
# Minimum Value [households]: 2.0
# Maximum Value [households]: 4930.0
# Skewness [households]: 3.5597534116462914
# Average Values [median_income]: 3.8072717999999997
# Most Frequent Value [median_income]: 15.0001
# Standard Deviation [median_income]: 1.854511729691479
# Median [median_income]: 3.4871499999999997
# Minimum Value [median_income]: 0.4999
# Maximum Value [median_income]: 15.0001
# Skewness [median_income]: 1.6985117348319874
# Average Values [median_house_value]: 205846.275
# Most Frequent Value [median_house_value]: 500001.0
# Standard Deviation [median_house_value]: 113119.68746964628
# Median [median_house_value]: 177650.0
# Minimum Value [median_house_value]: 22500.0
# Maximum Value [median_house_value]: 500001.0
# Skewness [median_house_value]: 0.9895619132015638
# Handling Missing Values:
# 1. Remove rows with missing values
# 2. Impute missing values with mean
# 3. Impute missing values with median
# 4. Impute missing values with a custom value
# Enter your choice (1/2/3/4): 3
